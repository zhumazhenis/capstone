# %% [markdown]
# ### Sobel Filter

# %%
import cv2
import numpy as np
from scipy.signal import convolve2d
from scipy import ndimage
import matplotlib.pyplot as plt

# %%
# Read image
roadGrayImg = cv2.imread('road.jpg', 0)

# %%
v1 = np.matrix([1, 2, 1])
v2 = np.matrix([-1, 0, 1])

# Sobel filter matrices
Kx = v1.T * v2
Ky = v2.T * v1

# Apply Sobel gilter
Gx = convolve2d(roadGrayImg, Kx, "same", "symm") 
Gy = convolve2d(roadGrayImg, Ky, "same", "symm")
G = np.sqrt(Gx ** 2 + Gy ** 2)

# %%
plt.imshow(G, cmap='gray')
plt.show()

# %% [markdown]
# ### Write Original Gray Image to txt file

# %%
with open('road.txt', 'w') as f:
    f.write("%s %s\n" % (len(roadGrayImg), len(roadGrayImg[0])))
    for row in roadGrayImg:
        for cell in row:
            f.write("%s " %cell)
        f.write("\n")

# %% [markdown]
# ### Read Edge Detected Image (generated by C++)

# %%
f = open('edgeRoad.txt', 'r')
line = f.readline().split()
rows = int(line[0])
cols = int(line[1])
filteredMatrix = []
for i in range(rows):
    row = [int(x) for x in f.readline().split()]
    filteredMatrix.append(row)
    
# edge image
edgeRoadGrayImg = np.array(filteredMatrix)

# %%
plt.imshow(edgeRoadGrayImg, cmap='gray')
plt.show()

# %% [markdown]
# ### BMP: extracted using C++

# %%
f = open('lena512.txt', 'r')
line = f.readline().split()
rows = int(line[0])
cols = int(line[1])
filteredMatrix = []
for i in range(rows):
    row = [int(x) for x in f.readline().split()]
    filteredMatrix.append(row)
    
lenaCpp = np.array(filteredMatrix)
plt.imshow(lenaCpp, cmap='gray')
plt.show()
lenaCpp
# Out:
# array([[162, 162, 162, ..., 170, 155, 128],
#        [162, 162, 162, ..., 170, 155, 128],
#        [162, 162, 162, ..., 170, 155, 128],
#        ...,
#        [ 44,  44,  55, ..., 104, 105, 108],
#        [128, 128, 128, ..., 255, 255,   0],
#        [  0,   0,   0, ..., 127, 127,   0]])

# %% [markdown]
# ### BMP: read using Python

# %%
lenaPython = cv2.imread('lena512.bmp', 0)
plt.imshow(lenaPython, cmap='gray')
plt.show()
lenaPython
# Out:
# array([[162, 162, 162, ..., 170, 155, 128],
#        [162, 162, 162, ..., 170, 155, 128],
#        [162, 162, 162, ..., 170, 155, 128],
#        ...,
#        [ 43,  43,  50, ..., 104, 100,  98],
#        [ 44,  44,  55, ..., 104, 105, 108],
#        [ 44,  44,  55, ..., 104, 105, 108]], dtype=uint8)
